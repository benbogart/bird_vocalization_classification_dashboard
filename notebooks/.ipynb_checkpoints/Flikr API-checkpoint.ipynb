# %%
import requests

# %%
flikr_key = '9ed6feedf4ed3df4f12101958364b9bb'
flickr_ecret = 'b47291883d79f6ba'

# %%
query = {
    'method':'flickr.photos.search',
    'format':'json',
    'api_key':flikr_key,
    'tags':'Setophaga ruticilla',
    'extras':'description, license, date_upload, date_taken, owner_name, icon_server, original_format, last_update, geo, tags, machine_tags, o_dims, views, media, path_alias, url_sq, url_t, url_s, url_q, url_m, url_n, url_z, url_c, url_l, url_o',
    'per_page':5,
    "nojsoncallback":"1",
    'sort','relevance'
}

# %%
r = requests.get('https://www.flickr.com/services/rest/', params=query)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'photos': {'page': 1,
#   'pages': 500,
#   'perpage': 5,
#   'total': '2497',
#   'photo': [{'id': '51117150955',
#     'owner': '18217058@N04',
#     'secret': 'a054f453f9',
#     'server': '65535',
#     'farm': 66,
#     'title': 'American redstart / Húmskríkja (Setophaga ruticilla)',
#     'ispublic': 1,
#     'isfriend': 0,
#     'isfamily': 0,
#     'license': '0',
#     'description': {'_content': 'La Fortuna, Alajuela province, Costa Rica'},
#     'dateupload': '1618443213',
#     'lastupdate': '1618477662',
#     'datetaken': '2020-01-07 17:55:59',
#     'datetakengranularity': '0',
#     'datetakenunknown': '0',
#     'ownername': 'thorrisig',
#     'iconserver': '65535',
#     'iconfarm': 66,
#     'views': '59',
#     'tags': 'animals costarica lafortuna americanredstart setophagaruticilla dýr fuglar alajuelaprovince húmskríkja 07012020 kostaríka bird birds thorri dorres spörfuglar sigurgeirsson thorfinnur thorrisig þorrisig thorfinnursigurgeirsson sigurgeirssonþorfinnur þorri þorfinnur þorfinnursigurgeirsson',
#     'machine_tags': '',
#     'latitude': 0,
#     'longitude': 0,
#     'accuracy': 0,
#     'context': 0,
#     'media': 'photo',
#     'media_status': 'ready',
#     'url_sq': 'https://live.staticflickr.com/65535/51117150955_a054f453f9_s.jpg',
#     'height_sq': 75,
#     'width_sq': 75,
#     'url_t': 'https://live.staticflickr.com/65535/51117150955_a054f453f9_t.jpg',
#     'height_t': 67,
#     'width_t': 100,
#     'url_s': 'https://live.staticflickr.com/65535/51117150955_a054f453f9_m.jpg',
#     'height_s': 160,
#     'width_s': 240,
#     'url_q': 'https://live.staticflickr.com/65535/51117150955_a054f453f9_q.jpg',
#     'height_q': 150,
#     'width_q': 150,
#     'url_m': 'https://live.staticflickr.com/65535/51117150955_a054f453f9.jpg',
#     'height_m': 333,
#     'width_m': 500,
#     'url_n': 'https://live.staticflickr.com/65535/51117150955_a054f453f9_n.jpg',
#     'height_n': 213,
#     'width_n': 320,
#     'url_z': 'https://live.staticflickr.com/65535/51117150955_a054f453f9_z.jpg',
#     'height_z': 426,
#     'width_z': 640,
#     'url_c': 'https://live.staticflickr.com/65535/51117150955_a054f453f9_c.jpg',
#     'height_c': 533,
#     'width_c': 800,
#     'url_l': 'https://live.staticflickr.com/65535/51117150955_a054f453f9_b.jpg',
#     'height_l': 682,
#     'width_l': 1024,
#     'pathalias': 'dorres'},
#    {'id': '51114907473',
#     'owner': '104632994@N05',
#     'secret': 'cf98144a52',
#     'server': '65535',
#     'farm': 66,
#     'title': 'GH6A77585cvm',
#     'ispublic': 1,
#     'isfriend': 0,
#     'isfamily': 0,
#     'license': '0',
#     'description': {'_content': 'Candelita - American redstart - (Setophaga ruticilla)'},
#     'dateupload': '1618388503',
#     'lastupdate': '1618674132',
#     'datetaken': '2016-12-05 14:38:37',
#     'datetakengranularity': '0',
#     'datetakenunknown': '0',
#     'ownername': 'jmvillarroya',
#     'iconserver': '7923',
#     'iconfarm': 8,
#     'views': '41',
#     'tags': 'jmvillarroya candelita americanredstart setophagaruticilla',
#     'machine_tags': '',
#     'latitude': 0,
#     'longitude': 0,
#     'accuracy': 0,
#     'context': 0,
#     'media': 'photo',
#     'media_status': 'ready',
#     'url_sq': 'https://live.staticflickr.com/65535/51114907473_cf98144a52_s.jpg',
#     'height_sq': 75,
#     'width_sq': 75,
#     'url_t': 'https://live.staticflickr.com/65535/51114907473_cf98144a52_t.jpg',
#     'height_t': 67,
#     'width_t': 100,
#     'url_s': 'https://live.staticflickr.com/65535/51114907473_cf98144a52_m.jpg',
#     'height_s': 160,
#     'width_s': 240,
#     'url_q': 'https://live.staticflickr.com/65535/51114907473_cf98144a52_q.jpg',
#     'height_q': 150,
#     'width_q': 150,
#     'url_m': 'https://live.staticflickr.com/65535/51114907473_cf98144a52.jpg',
#     'height_m': 333,
#     'width_m': 500,
#     'url_n': 'https://live.staticflickr.com/65535/51114907473_cf98144a52_n.jpg',
#     'height_n': 213,
#     'width_n': 320,
#     'url_z': 'https://live.staticflickr.com/65535/51114907473_cf98144a52_z.jpg',
#     'height_z': 427,
#     'width_z': 640,
#     'url_c': 'https://live.staticflickr.com/65535/51114907473_cf98144a52_c.jpg',
#     'height_c': 533,
#     'width_c': 800,
#     'url_l': 'https://live.staticflickr.com/65535/51114907473_cf98144a52_b.jpg',
#     'height_l': 683,
#     'width_l': 1024,
#     'pathalias': None},
#    {'id': '51112456106',
#     'owner': '34674638@N05',
#     'secret': '502259fb1d',
#     'server': '65535',
#     'farm': 66,
#     'title': 'American Redstart (m)',
#     'ispublic': 1,
#     'isfriend': 0,
#     'isfamily': 0,
#     'license': '0',
#     'description': {'_content': 'Lake Ida Park, Florida'},
#     'dateupload': '1618266043',
#     'lastupdate': '1618573843',
#     'datetaken': '2021-04-12 14:02:59',
#     'datetakengranularity': '0',
#     'datetakenunknown': '0',
#     'ownername': 'arielfischer',
#     'iconserver': '65535',
#     'iconfarm': 66,
#     'views': '207',
#     'tags': 'setophagaruticilla americanredstart redstart schnäpperwaldsänger waldsänger candelitanorteña parulineflamboyante paruline codirossoamericano ハゴロモムシクイ mariquitaderabovermelho американскаягорихвостка רוטיצילה 橙尾鸲莺',
#     'machine_tags': '',
#     'originalsecret': '5a1759ed77',
#     'originalformat': 'jpg',
#     'latitude': 0,
#     'longitude': 0,
#     'accuracy': 0,
#     'context': 0,
#     'media': 'photo',
#     'media_status': 'ready',
#     'url_sq': 'https://live.staticflickr.com/65535/51112456106_502259fb1d_s.jpg',
#     'height_sq': 75,
#     'width_sq': 75,
#     'url_t': 'https://live.staticflickr.com/65535/51112456106_502259fb1d_t.jpg',
#     'height_t': 67,
#     'width_t': 100,
#     'url_s': 'https://live.staticflickr.com/65535/51112456106_502259fb1d_m.jpg',
#     'height_s': 160,
#     'width_s': 240,
#     'url_q': 'https://live.staticflickr.com/65535/51112456106_502259fb1d_q.jpg',
#     'height_q': 150,
#     'width_q': 150,
#     'url_m': 'https://live.staticflickr.com/65535/51112456106_502259fb1d.jpg',
#     'height_m': 333,
#     'width_m': 500,
#     'url_n': 'https://live.staticflickr.com/65535/51112456106_502259fb1d_n.jpg',
#     'height_n': 213,
#     'width_n': 320,
#     'url_z': 'https://live.staticflickr.com/65535/51112456106_502259fb1d_z.jpg',
#     'height_z': 427,
#     'width_z': 640,
#     'url_c': 'https://live.staticflickr.com/65535/51112456106_502259fb1d_c.jpg',
#     'height_c': 533,
#     'width_c': 800,
#     'url_l': 'https://live.staticflickr.com/65535/51112456106_502259fb1d_b.jpg',
#     'height_l': 682,
#     'width_l': 1024,
#     'url_o': 'https://live.staticflickr.com/65535/51112456106_5a1759ed77_o.jpg',
#     'height_o': 2268,
#     'width_o': 3403,
#     'pathalias': 'arielfischer'},
#    {'id': '51110200478',
#     'owner': '151361315@N06',
#     'secret': '436cc5befb',
#     'server': '65535',
#     'farm': 66,
#     'title': 'American Redstart subadult male calling • Magee Marsh, OH • 2015',
#     'ispublic': 1,
#     'isfriend': 0,
#     'isfamily': 0,
#     'license': '0',
#     'description': {'_content': 'American Redstart subadult male calling • Magee Marsh, OH • 2015'},
#     'o_width': '3017',
#     'o_height': '2011',
#     'dateupload': '1618181065',
#     'lastupdate': '1618181111',
#     'datetaken': '2015-05-22 09:21:13',
#     'datetakengranularity': '0',
#     'datetakenunknown': '0',
#     'ownername': 'suephillips4',
#     'iconserver': '65535',
#     'iconfarm': 66,
#     'views': '4',
#     'tags': 'americanredstart warbler redstart male subadult sing call birdsong bird feathers springplumage songbird communicate setophagaruticilla mageemarsh wildlife nature passerine profile',
#     'machine_tags': '',
#     'originalsecret': 'e114173d1a',
#     'originalformat': 'jpg',
#     'latitude': 0,
#     'longitude': 0,
#     'accuracy': 0,
#     'context': 0,
#     'media': 'photo',
#     'media_status': 'ready',
#     'url_sq': 'https://live.staticflickr.com/65535/51110200478_436cc5befb_s.jpg',
#     'height_sq': 75,
#     'width_sq': 75,
#     'url_t': 'https://live.staticflickr.com/65535/51110200478_436cc5befb_t.jpg',
#     'height_t': 67,
#     'width_t': 100,
#     'url_s': 'https://live.staticflickr.com/65535/51110200478_436cc5befb_m.jpg',
#     'height_s': 160,
#     'width_s': 240,
#     'url_q': 'https://live.staticflickr.com/65535/51110200478_436cc5befb_q.jpg',
#     'height_q': 150,
#     'width_q': 150,
#     'url_m': 'https://live.staticflickr.com/65535/51110200478_436cc5befb.jpg',
#     'height_m': 333,
#     'width_m': 500,
#     'url_n': 'https://live.staticflickr.com/65535/51110200478_436cc5befb_n.jpg',
#     'height_n': 213,
#     'width_n': 320,
#     'url_z': 'https://live.staticflickr.com/65535/51110200478_436cc5befb_z.jpg',
#     'height_z': 427,
#     'width_z': 640,
#     'url_c': 'https://live.staticflickr.com/65535/51110200478_436cc5befb_c.jpg',
#     'height_c': 533,
#     'width_c': 800,
#     'url_l': 'https://live.staticflickr.com/65535/51110200478_436cc5befb_b.jpg',
#     'height_l': 683,
#     'width_l': 1024,
#     'url_o': 'https://live.staticflickr.com/65535/51110200478_e114173d1a_o.jpg',
#     'height_o': 2011,
#     'width_o': 3017,
#     'pathalias': 'suephillips'},
#    {'id': '51110294306',
#     'owner': '151361315@N06',
#     'secret': '7d8de970a7',
#     'server': '65535',
#     'farm': 66,
#     'title': 'American Redstart subadult male • Magee Marsh, OH • 2015',
#     'ispublic': 1,
#     'isfriend': 0,
#     'isfamily': 0,
#     'license': '0',
#     'description': {'_content': 'American Redstart subadult male • Magee Marsh, OH • 2015'},
#     'o_width': '3857',
#     'o_height': '2892',
#     'dateupload': '1618181065',
#     'lastupdate': '1618181111',
#     'datetaken': '2015-05-22 10:38:08',
#     'datetakengranularity': '0',
#     'datetakenunknown': '0',
#     'ownername': 'suephillips4',
#     'iconserver': '65535',
#     'iconfarm': 66,
#     'views': '3',
#     'tags': 'americanredstart warbler redstart male subadult bird feathers springplumage songbird setophagaruticilla mageemarsh wildlife nature passerine profile closeup',
#     'machine_tags': '',
#     'originalsecret': '7fdcbb1787',
#     'originalformat': 'jpg',
#     'latitude': 0,
#     'longitude': 0,
#     'accuracy': 0,
#     'context': 0,
#     'media': 'photo',
#     'media_status': 'ready',
#     'url_sq': 'https://live.staticflickr.com/65535/51110294306_7d8de970a7_s.jpg',
#     'height_sq': 75,
#     'width_sq': 75,
#     'url_t': 'https://live.staticflickr.com/65535/51110294306_7d8de970a7_t.jpg',
#     'height_t': 75,
#     'width_t': 100,
#     'url_s': 'https://live.staticflickr.com/65535/51110294306_7d8de970a7_m.jpg',
#     'height_s': 180,
#     'width_s': 240,
#     'url_q': 'https://live.staticflickr.com/65535/51110294306_7d8de970a7_q.jpg',
#     'height_q': 150,
#     'width_q': 150,
#     'url_m': 'https://live.staticflickr.com/65535/51110294306_7d8de970a7.jpg',
#     'height_m': 375,
#     'width_m': 500,
#     'url_n': 'https://live.staticflickr.com/65535/51110294306_7d8de970a7_n.jpg',
#     'height_n': 240,
#     'width_n': 320,
#     'url_z': 'https://live.staticflickr.com/65535/51110294306_7d8de970a7_z.jpg',
#     'height_z': 480,
#     'width_z': 640,
#     'url_c': 'https://live.staticflickr.com/65535/51110294306_7d8de970a7_c.jpg',
#     'height_c': 600,
#     'width_c': 800,
#     'url_l': 'https://live.staticflickr.com/65535/51110294306_7d8de970a7_b.jpg',
#     'height_l': 768,
#     'width_l': 1024,
#     'url_o': 'https://live.staticflickr.com/65535/51110294306_7fdcbb1787_o.jpg',
#     'height_o': 2892,
#     'width_o': 3857,
#     'pathalias': 'suephillips'}]},
#  'stat': 'ok'}
